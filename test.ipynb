# %% [markdown]
# <a href="https://colab.research.google.com/github/akashchauhan087/Artificial-Intellagence/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Aks")
# Out:
# Hello Aks

# %%
print("welcome to Azure Kubernetes Service")
# Out:
# welcome to Azure Kubernetes Service
